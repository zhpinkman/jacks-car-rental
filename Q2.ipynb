# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
prices = np.random.normal(loc=20, scale=5, size=100)

# %%
sns.scatterplot(data=prices)
# Out:
# <AxesSubplot:>

# %%
requests = np.round(np.random.normal(loc=5, scale=1, size=100))

# %%
5**100
# Out:
# 7888609052210118054117285652827862296732064351090230047702789306640625

# %%
sns.histplot(data=requests)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
requests = [np.random.poisson(lam=5) for i in range(500)]

# %%
sns.histplot(data=requests)
# Out:
# <AxesSubplot:ylabel='Count'>
